# %%
#Importing the packages

import pandas as pd
import numpy as np
import missingno as mn
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
#Definignt he column headings 
cols = ["Age","Workclass","Final_Weight","Education","Education_Num","Marital_Status","Occupation","Relationship","Race","Sex","Capital_Gain","Capital_Loss","Hours_Per_Week","Native_Country","Income"]

# Reading the data to dataframe
df = pd.read_csv('adult.data',names=cols,skipinitialspace=True)
df
# Out:
#        Age         Workclass  Final_Weight   Education  Education_Num  \
# 0       39         State-gov         77516   Bachelors             13
# 1       50  Self-emp-not-inc         83311   Bachelors             13
# 2       38           Private        215646     HS-grad              9
# 3       53           Private        234721        11th              7
# 4       28           Private        338409   Bachelors             13
# ...    ...               ...           ...         ...            ...
# 32556   27           Private        257302  Assoc-acdm             12
# 32557   40           Private        154374     HS-grad              9
# 32558   58           Private        151910     HS-grad              9
# 32559   22           Private        201490     HS-grad              9
# 32560   52      Self-emp-inc        287927     HS-grad              9
#
#            Marital_Status         Occupation   Relationship   Race     Sex  \
# ...

# %%
#printing first five rows using head() method
df.head()
# Out:
#    Age         Workclass  Final_Weight  Education  Education_Num  \
# 0   39         State-gov         77516  Bachelors             13
# 1   50  Self-emp-not-inc         83311  Bachelors             13
# 2   38           Private        215646    HS-grad              9
# 3   53           Private        234721       11th              7
# 4   28           Private        338409  Bachelors             13
#
#        Marital_Status         Occupation   Relationship   Race     Sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    Capital_Gain  Capital_Loss  Hours_Per_Week Native_Country Income
# 0          2174             0              40  United-States  <=50K
# ...

# %%
#Printing last five rows using tail() method
df.tail()
# Out:
#        Age     Workclass  Final_Weight   Education  Education_Num  \
# 32556   27       Private        257302  Assoc-acdm             12
# 32557   40       Private        154374     HS-grad              9
# 32558   58       Private        151910     HS-grad              9
# 32559   22       Private        201490     HS-grad              9
# 32560   52  Self-emp-inc        287927     HS-grad              9
#
#            Marital_Status         Occupation Relationship   Race     Sex  \
# 32556  Married-civ-spouse       Tech-support         Wife  White  Female
# 32557  Married-civ-spouse  Machine-op-inspct      Husband  White    Male
# 32558             Widowed       Adm-clerical    Unmarried  White  Female
# 32559       Never-married       Adm-clerical    Own-child  White    Male
# 32560  Married-civ-spouse    Exec-managerial         Wife  White  Female
#
#        Capital_Gain  Capital_Loss  Hours_Per_Week Native_Country Income
# ...

# %%
#Getting the DataFrame Column Charecteristics using info()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32561 non-null  int64
#  1   Workclass       32561 non-null  object
#  2   Final_Weight    32561 non-null  int64
#  3   Education       32561 non-null  object
#  4   Education_Num   32561 non-null  int64
#  5   Marital_Status  32561 non-null  object
#  6   Occupation      32561 non-null  object
#  7   Relationship    32561 non-null  object
#  8   Race            32561 non-null  object
#  9   Sex             32561 non-null  object
#  10  Capital_Gain    32561 non-null  int64
#  11  Capital_Loss    32561 non-null  int64
#  12  Hours_Per_Week  32561 non-null  int64
#  13  Native_Country  32561 non-null  object
#  14  Income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %% [markdown]
# # HANDLING THE MISSING VALUES

# %%
#Checking for NUll Values or Missing Values
df.isnull().sum()
# Out:
# Age               0
# Workclass         0
# Final_Weight      0
# Education         0
# Education_Num     0
# Marital_Status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Capital_Gain      0
# Capital_Loss      0
# Hours_Per_Week    0
# Native_Country    0
# Income            0
# dtype: int64

# %%
#It is Observed in the data set that some missing values are replaced by '?'
df.isin(['?']).sum()
# Out:
# Age                  0
# Workclass         1836
# Final_Weight         0
# Education            0
# Education_Num        0
# Marital_Status       0
# Occupation        1843
# Relationship         0
# Race                 0
# Sex                  0
# Capital_Gain         0
# Capital_Loss         0
# Hours_Per_Week       0
# Native_Country     583
# Income               0
# dtype: int64

# %%
#Replacing the '?' with 'Nan'
df['Workclass'] = df['Workclass'].replace('?', np.nan)
df['Occupation'] = df['Occupation'].replace('?', np.nan)
df['Native_Country'] = df['Native_Country'].replace('?', np.nan)

# %%
#Checking for NUll Values or Missing Values
df.isnull().sum()
# Out:
# Age                  0
# Workclass         1836
# Final_Weight         0
# Education            0
# Education_Num        0
# Marital_Status       0
# Occupation        1843
# Relationship         0
# Race                 0
# Sex                  0
# Capital_Gain         0
# Capital_Loss         0
# Hours_Per_Week       0
# Native_Country     583
# Income               0
# dtype: int64

# %%
#Dropping the Null Values
df.dropna(inplace=True)

# %%
#Checking for Duplicate Records
df.duplicated().sum()
# Out:
# 23

# %%
df = df.drop_duplicates()
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %%
#Changing the Income Column values to 0 if <=50k else 1 for easy processing
df['Income']=df['Income'].map({"<=50K": 0, ">50K": 1})
df.head()
# Out:
# <ipython-input-195-510221759286>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Income']=df['Income'].map({"<=50K": 0, ">50K": 1})
#    Age         Workclass  Final_Weight  Education  Education_Num  \
# 0   39         State-gov         77516  Bachelors             13
# 1   50  Self-emp-not-inc         83311  Bachelors             13
# 2   38           Private        215646    HS-grad              9
# 3   53           Private        234721       11th              7
# 4   28           Private        338409  Bachelors             13
#
#        Marital_Status         Occupation   Relationship   Race     Sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %% [markdown]
# In this case I Consider the below features plays an important role in determining if a person can earn above or below 50K.
#
#
# 1)Edcuation
# 2)Workclass
# 3)Occupation
# 4)Hours_Per_Week

# %% [markdown]
# ## UNIVARIATE ANALYSIS

# %%
#Getting the counts of Income
df['Income'].value_counts()
# Out:
# 0    22633
# 1     7506
# Name: Income, dtype: int64

# %%
df['Income'].value_counts().plot(kind='bar',color=["Blue","Orange"])

# %%
df['Income'].value_counts().plot(kind='pie',autopct='%.2f')

# %% [markdown]
# SO In the provided data we have 75% information on people who earn less then 50k income and around 25% information on the high income class.

# %% [markdown]
# ## BIVARIATE ANALYSIS

# %%
#Relationship between Hours_Per_Week and Income using box Plot

sns.boxplot(x = 'Income', y = 'Hours_Per_Week', data=df[cols])

# %% [markdown]
# It is Observed that people who work for 40 hrs to 50 Hrs a week are likely to earn above 50K but on the other hand there are some outliers who work more than 50 hrs a week but still income is less than 50k.
#
# We conclude here that Hours_Per_week and Income are not linearly releated.

# %%
df[(df["Income"]==0) & (df["Hours_Per_Week"]>50)].groupby(["Occupation"]).agg({"Hours_Per_Week":"mean"})
# Out:
#                    Hours_Per_Week
# Occupation
# Adm-clerical            59.904762
# Armed-Forces            60.000000
# Craft-repair            61.531835
# Exec-managerial         62.307420
# Farming-fishing         68.570815
# Handlers-cleaners       61.213115
# Machine-op-inspct       60.813333
# Other-service           66.070423
# Priv-house-serv         73.666667
# Prof-specialty          63.682927
# Protective-serv         64.929825
# Sales                   60.608247
# Tech-support            63.324324
# Transport-moving        64.263889

# %% [markdown]
# Group of people working more then 50hrs and earning less income are from Priv-house-serv occupation

# %%
df[(df["Income"]==1) & (df["Hours_Per_Week"]<50)].groupby(["Occupation"]).agg({"Hours_Per_Week":"mean"})
# Out:
#                    Hours_Per_Week
# Occupation
# Adm-clerical            38.485849
# Armed-Forces            40.000000
# Craft-repair            40.670149
# Exec-managerial         40.233840
# Farming-fishing         38.707317
# Handlers-cleaners       39.528571
# Machine-op-inspct       40.864078
# Other-service           36.731959
# Priv-house-serv         35.000000
# Prof-specialty          39.023236
# Protective-serv         40.072848
# Sales                   39.867173
# Tech-support            38.682203
# Transport-moving        40.188889

# %% [markdown]
# People who earn more than 50K are mostly working 40 hrs per week

# %%
tot_lowpaying = df[df["Income"]==0].shape[0]
num_hardworking = df[(df["Income"]==0) & (df["Hours_Per_Week"]>=50)].shape[0]
hardworking_ppl = (num_hardworking/tot_lowpaying) * 100

# %%
print(f"there are a total of {tot_lowpaying} people who earn less than 50K, \n in which number of people who work more than 50hrs are {num_hardworking} and their proportion is {hardworking_ppl}")
# Out:
# there are a total of 22633 people who earn less than 50K,
#  in which number of people who work more than 50hrs are 3502 and their proportion is 15.472981929041666

# %%
tot_highpaying = df[df["Income"]==1].shape[0]
num_smart = df[(df["Income"]==1) & (df["Hours_Per_Week"]<50)].shape[0]
smartworking_ppl = (num_smart/tot_highpaying) * 100

# %%
print(f"there are a total of {tot_highpaying} people who earn more than 50K, \n in which number of people who work less than 50hrs are {num_smart} and their proportion is {smartworking_ppl}")
# Out:
# there are a total of 7506 people who earn more than 50K,
#  in which number of people who work less than 50hrs are 4818 and their proportion is 64.18864908073542

# %%
#Exploring Relationship between Education And Income
sns.set(rc = {'figure.figsize':(15,8)})
sns.countplot(y = "Education", hue = "Income", data = df)

# %% [markdown]
# By this Graph we can say that People who has done Masters and Doctrate and Prof-School are earning more than 50k Compared to other Education Catagories.

# %%
#Relationship between Age and Income
pd.crosstab(df.Age, df.Income).plot(kind="line",
                                   figsize=(10, 6))
plt.title("Income and Age")
# Out:
# Text(0.5, 1.0, 'Income and Age')

# %% [markdown]
# In the above graph we can observe that population aged between 20-28 are likely to earn less income and
# the population aged between 30-40 are earning more income as there is a spike in the graph.

# %%
pd.crosstab(df.Sex, df.Income).plot(kind="bar",
                                   figsize=(10, 6))
plt.title("Relationship wrto Genders")
# Out:
# Text(0.5, 1.0, 'Relationship wrto Genders')

# %% [markdown]
# As per Gender, Females who earn >50K is comparetively less than the Males.

# %%
sns.scatterplot(data=df,x="Education_Num",y="Hours_Per_Week",hue="Income")

# %% [markdown]
# With increase in Education_Num and Hours_per_week, Income bracket also changes

# %%
sns.scatterplot(data=df,x="Age",y="Hours_Per_Week",hue="Income")

# %% [markdown]
# Income based on age and Hours_Per_Week is very scattered

# %%
corr = df.corr()

sns.set(rc = {'figure.figsize':(15,8)})
sns.heatmap(corr,annot=True)

# %% [markdown]
# Education_Num has the highest correlation on Income

# %%
sns.pairplot(df)

# %% [markdown]
# Although we already know some of the main figures,
# this mega scatter plot gives us a reasonable idea about variables relationships.
#
#
# Clearly there isn't any good linear relationship between any of the above variables against Income.
#
# We need to include either more variable or do feature engineering.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30139 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             30139 non-null  int64
#  1   Workclass       30139 non-null  object
#  2   Final_Weight    30139 non-null  int64
#  3   Education       30139 non-null  object
#  4   Education_Num   30139 non-null  int64
#  5   Marital_Status  30139 non-null  object
#  6   Occupation      30139 non-null  object
#  7   Relationship    30139 non-null  object
#  8   Race            30139 non-null  object
#  9   Sex             30139 non-null  object
#  10  Capital_Gain    30139 non-null  int64
#  11  Capital_Loss    30139 non-null  int64
#  12  Hours_Per_Week  30139 non-null  int64
#  13  Native_Country  30139 non-null  object
#  14  Income          30139 non-null  int64
# dtypes: int64(7), object(8)
# memory usage: 4.9+ MB

# %% [markdown]
# Let's start by dropping Education as Education_Num and Education represents same information

# %%
df.drop("Education",axis=1,inplace = True)
# Out:
# C:\Users\Akash Guje\anaconda3\lib\site-packages\pandas\core\frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df.head()
# Out:
#    Age         Workclass  Final_Weight  Education_Num      Marital_Status  \
# 0   39         State-gov         77516             13       Never-married
# 1   50  Self-emp-not-inc         83311             13  Married-civ-spouse
# 2   38           Private        215646              9            Divorced
# 3   53           Private        234721              7  Married-civ-spouse
# 4   28           Private        338409             13  Married-civ-spouse
#
#           Occupation   Relationship   Race     Sex  Capital_Gain  \
# 0       Adm-clerical  Not-in-family  White    Male          2174
# 1    Exec-managerial        Husband  White    Male             0
# 2  Handlers-cleaners  Not-in-family  White    Male             0
# 3  Handlers-cleaners        Husband  Black    Male             0
# 4     Prof-specialty           Wife  Black  Female             0
#
#    Capital_Loss  Hours_Per_Week Native_Country  Income
# 0             0              40  United-States       0
# ...

# %% [markdown]
# The difference in Capital_Gain and Capital_Loss gives us the profit/loss. Let's create a new column and replace them with
# these two columns

# %%
df["Profit/Loss"] = df["Capital_Gain"] - df["Capital_Loss"]
df.drop(["Capital_Gain","Capital_Loss"],inplace=True,axis=1)
# Out:
# <ipython-input-216-9d70ec9b6a80>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Profit/Loss"] = df["Capital_Gain"] - df["Capital_Loss"]
# C:\Users\Akash Guje\anaconda3\lib\site-packages\pandas\core\frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df.head()
# Out:
#    Age         Workclass  Final_Weight  Education_Num      Marital_Status  \
# 0   39         State-gov         77516             13       Never-married
# 1   50  Self-emp-not-inc         83311             13  Married-civ-spouse
# 2   38           Private        215646              9            Divorced
# 3   53           Private        234721              7  Married-civ-spouse
# 4   28           Private        338409             13  Married-civ-spouse
#
#           Occupation   Relationship   Race     Sex  Hours_Per_Week  \
# 0       Adm-clerical  Not-in-family  White    Male              40
# 1    Exec-managerial        Husband  White    Male              13
# 2  Handlers-cleaners  Not-in-family  White    Male              40
# 3  Handlers-cleaners        Husband  Black    Male              40
# 4     Prof-specialty           Wife  Black  Female              40
#
#   Native_Country  Income  Profit/Loss
# 0  United-States       0         2174
# 1  United-States       0            0
# ...

# %%
sns.pairplot(df)

# %% [markdown]
# since there are many categories with categorical data, using label encoder just to see how they are linearly related to Income
# and not using one hot encoding since that will result in too many columns

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df = df.apply(LabelEncoder().fit_transform)

# %%
df.head()
# Out:
#    Age  Workclass  Final_Weight  Education_Num  Marital_Status  Occupation  \
# 0   22          5          2491             12               4           0
# 1   33          4          2727             12               2           3
# 2   21          2         13188              8               0           5
# 3   36          2         14354              6               2           5
# 4   11          2         18120             12               2           9
#
#    Relationship  Race  Sex  Hours_Per_Week  Native_Country  Income  \
# 0             1     4    1              39              38       0
# 1             0     4    1              12              38       0
# 2             1     4    1              39              38       0
# 3             0     2    1              39              38       0
# 4             5     2    0              39               4       0
#
#    Profit/Loss
# 0          113
# 1           89
# 2           89
# 3           89
# 4           89

# %%
corr = df.corr()
sns.set(rc = {'figure.figsize':(15,8)})
sns.heatmap(corr,annot=True)

# %% [markdown]
# It turns out that none of the features have high correlation with income. Only Age, Education_Num, Relationship, Sex,
# Hours and profit/Loss have low correlation. Interestingly Workclass and Occupation ain't showing any linear relationship
# with Income. Race, Final_weight and Native_Country are poor predictors of Income so they can be dropped from further analysis.

# %%
df.drop(["Race","Final_Weight","Native_Country"],axis=1,inplace=True)

# %%
df.head()
# Out:
#    Age  Workclass  Education_Num  Marital_Status  Occupation  Relationship  \
# 0   22          5             12               4           0             1
# 1   33          4             12               2           3             0
# 2   21          2              8               0           5             1
# 3   36          2              6               2           5             0
# 4   11          2             12               2           9             5
#
#    Sex  Hours_Per_Week  Income  Profit/Loss
# 0    1              39       0          113
# 1    1              12       0           89
# 2    1              39       0           89
# 3    1              39       0           89
# 4    0              39       0           89
